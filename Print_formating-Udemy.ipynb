# %%
condiments="Jam"

# %%
condiments
# Out:
# 'Jam'

# %%
change=condiments[1:]

# %%
change
# Out:
# 'am'

# %%
new="S"+change

# %%
new
# Out:
# 'Sam'

# %%
x="Hello World"

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
print("This is a string {}".format("Object"))
# Out:
# This is a string Object

# %%
print("This is the {} {} {} {}".format("Day", "that the Lord","has", "made"))
# Out:
# This is the Day that the Lord has made

# %%
print("The {2} {1} {0}".format("fox", "brown", "quick"))
# Out:
# The quick brown fox

# %%
print("The {q} {b} {f}".format(f="fox", b="brown", q="quick"))
# Out:
# The quick brown fox

# %%
result=100/77

# %%
result
# Out:
# 1.2987012987012987

# %%
print("The result was {r:2.4f}".format(r=result))
# Out:
# The result was 1.2987

# %%
LIST=[1,2,3,4,5,6,7,8,9,"FOUR","SIX"]

# %%
LIST
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 'FOUR', 'SIX']

# %%
LIST.append("FIVE")

# %%
LIST
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 'FOUR', 'SIX', 'FIVE']

# %%
LIST[::-1]
# Out:
# ['FIVE', 'SIX', 'FOUR', 9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
RLIST=LIST[::-1]

# %%
RLIST
# Out:
# ['FIVE', 'SIX', 'FOUR', 9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
RLIST.pop(3)
# Out:
# 9

# %%
RLIST
# Out:
# ['FIVE', 'SIX', 'FOUR', 8, 7, 6, 5, 4, 3, 1]

# %%
LIST.reverse()

# %%
LIST
# Out:
# ['FIVE', 'SIX', 'FOUR', 9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
LST=[7,8,5,3,4,9,7,8,1,2,12,13,34]

# %%
LST.sort()

# %%
LST
# Out:
# [1, 2, 3, 4, 5, 7, 7, 8, 8, 9, 12, 13, 34]
