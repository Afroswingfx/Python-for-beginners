# %%
hungry=True
if hungry:
    print("Feed Me!")
else:
    print("I'm not hungry")
# Out:
# Feed Me!

# %%
loc="Home"
if loc=="Auto shop":
    print("Cars are cool")
elif loc=="Bank":
    print("Money is cool")
elif loc=="Store":
    print("Welcome to the store")
    
else:
    print("I do not know much")
# Out:
# I do not know much

# %%
name="Sammy"
if name=="Frankie":
    print("Hello Frankie")
elif name=="Sammy"
