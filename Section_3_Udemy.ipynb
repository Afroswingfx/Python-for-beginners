# %%
2+1
# Out:
# 3

# %%
2*9
# Out:
# 18

# %%
9/3
# Out:
# 3.0

# %%
9%3
# Out:
# 0

# %%
9//3
# Out:
# 3

# %%
7%4
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
#Assigning variables

# %%
a=7

# %%
a
# Out:
# 7

# %%
a+a
# Out:
# 14

# %%
a=a*3

# %%
a
# Out:
# 21

# %%
type(a)
# Out:
# int

# %%
b=23.6

# %%
type(b)
# Out:
# float

# %%
my_income=3000
tax_rate=0.1
my_taxes=my_income*tax_rate
my_taxes
# Out:
# 300.0

# %%
#Strings
#Strings are ordered sequence, it meas we can use indexing and slicing to grab sub-sections of the string.
#Indexing notation uses[] notation after the string(or variable assigned to the string).
#Indexing allows you to grab a single character from the string

# %%
"Hello"
# Out:
# 'Hello'

# %%
"I'm going on a run"
# Out:
# "I'm going on a run"

# %%
print("I'm going on a run")
# Out:
# I'm going on a run

# %%
print("I am learning Python \non Udemy and Coursera")
# Out:
# I am learning Python
# on Udemy and Coursera

# %%
print("Jose is teaching me new \t Python concepts")
# Out:
# Jose is teaching me new 	 Python concepts

# %%
mystring="Hello World "

# %%
mystring
# Out:
# 'Hello World '

# %%
mystring[7]
# Out:
# 'o'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[-2]
# Out:
# 'd'

# %%
len(mystring)
# Out:
# 12

# %%
alphabets="abcdefghijklyfdsahd"

# %%
alphabets
# Out:
# 'abcdefghijklyfdsahd'

# %%
alphabets[3:8]
# Out:
# 'defgh'

# %%
alphabets.split("g")
# Out:
# ['abcdef', 'hijklyfdsahd']

# %%
alphabets[-6:-1]
# Out:
# 'fdsah'

# %%
alphabets[::3]
# Out:
# 'adgjysd'

# %%
alphabets[::-1]
# Out:
# 'dhasdfylkjihgfedcba'
